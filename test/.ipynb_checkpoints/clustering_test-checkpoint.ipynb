# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# sample data set from original paper
input_data = np.genfromtxt('sample.dat', delimiter=';', names='class, x1, x2, x3, x4, x5') 
# results generated by the original scala implementation
expected_result = np.genfromtxt('sample_result.dat', delimiter=';', names='class, x1, x2, x3, x4, x5')
